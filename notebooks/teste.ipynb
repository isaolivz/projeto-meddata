# %%
import pandas as pd

# Carregar o dataset integrado
df = pd.read_parquet('../data/processed/meddata_integrado_PR_2024_01.parquet')

print(f"Registros: {len(df):,}")
print(f"Colunas: {len(df.columns)}")
print(df.head())
print(df.info())
# Out:
# Registros: 2,700,310
# Colunas: 37
#   codigo_municipio id_hospital codigo_diagnostico data_internacao data_saida  \
# 0           410050     2781700               K359      2023-11-23 2023-11-24
# 1           410050     2781700               K359      2023-11-23 2023-11-24
# 2           410050     2781700               K359      2023-11-23 2023-11-24
# 3           410050     2781700               K359      2023-11-23 2023-11-24
# 4           410050     2781700               K359      2023-11-23 2023-11-24
#
#    valor_procedimento codigo_municipio_paciente  ano_competencia  \
# 0               99.73                    410050             2024
# 1               99.73                    410050             2024
# 2               99.73                    410050             2024
# 3               99.73                    410050             2024
# 4               99.73                    410050             2024
#
#    mes_competencia  dias_internacao  ...  esfera_classificacao  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2700310 entries, 0 to 2700309
# Data columns (total 37 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   codigo_municipio           object
#  1   id_hospital                object
#  2   codigo_diagnostico         object
#  3   data_internacao            datetime64[ns]
#  4   data_saida                 datetime64[ns]
#  5   valor_procedimento         float64
#  6   codigo_municipio_paciente  object
#  7   ano_competencia            int64
#  8   mes_competencia            int64
#  9   dias_internacao            int64
#  10  paciente_viajou            bool
#  11  dia_semana                 object
#  12  mes_ano                    period[M]
#  13  tipo_dia                   object
#  14  codigo_municipio_hospital  object
#  15  tipo_leito                 object
#  16  esfera                     object
#  17  tipo_unidade               object
#  18  nivel_hierarquico          object
# ...

# %%
df.isnull().sum()
# Out:
# codigo_municipio                   0
# id_hospital                        0
# codigo_diagnostico                 0
# data_internacao                    0
# data_saida                         0
# valor_procedimento                 0
# codigo_municipio_paciente          0
# ano_competencia                    0
# mes_competencia                    0
# dias_internacao                    0
# paciente_viajou                    0
# dia_semana                         0
# mes_ano                            0
# tipo_dia                           0
# codigo_municipio_hospital          0
# tipo_leito                         0
# esfera                             0
# tipo_unidade                       0
# nivel_hierarquico                  0
# natureza_juridica                  0
# leitos_totais                      0
# leitos_contratados                 0
# leitos_sus                         0
# leitos_nao_sus                     0
# tipo_leito_nome                    0
# ...
